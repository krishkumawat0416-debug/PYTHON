# %% [markdown]
# <a href="https://colab.research.google.com/github/krishkumawat0416-debug/PYTHON/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Normal Distribution
# from central_tendency (mean , median , mode) ---> left and right side equal data points
# Identification
# mean = 0 , standard deviation = 1

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop(columns = ['city', 'cough'])

# %%
df.head(2)
# Out:
#    age gender  fever has_covid
# 0   60   Male  103.0        No
# 1   27   Male  100.0       Yes

# %%
df['gender'] = df['gender'].map({"Male":0 , "Female":1})
df['has_covid'] = df['has_covid'].map({"No":0 , "Yes":1})

# %%
df.head(2)
# Out:
#    age  gender  fever  has_covid
# 0   60       0  103.0          0
# 1   27       0  100.0          1

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state = 42)

# %%
np.round(x_train.describe(),2)
# Out:
#          age  gender   fever
# count  72.00   72.00   72.00
# mean   43.53    0.64  100.74
# std    25.30    0.48    2.12
# min     5.00    0.00   98.00
# 25%    19.75    0.00   99.00
# 50%    47.00    1.00  101.00
# 75%    65.25    1.00  102.25
# max    83.00    1.00  104.00

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train_sc = sc.fit_transform(x_train) # fit means learn the parameters and transform means apply on that data

# %%
x_train_new = pd.DataFrame(x_train_sc , columns = x_train.columns)

# %%
x_train_new.head(2)
# Out:
#         age    gender     fever
# 0  0.217812  0.751809 -0.826113
# 1  0.974074  0.751809  0.125569

# %%
np.round(x_train_new.describe(),2)
# Out:
#          age  gender  fever
# count  72.00   72.00  72.00
# mean   -0.00    0.00  -0.00
# std     1.01    1.01   1.01
# min    -1.53   -1.33  -1.30
# 25%    -0.95   -1.33  -0.83
# 50%     0.14    0.75   0.13
# 75%     0.86    0.75   0.72
# max     1.57    0.75   1.55
