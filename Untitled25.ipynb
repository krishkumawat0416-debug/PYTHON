# %% [markdown]
# <a href="https://colab.research.google.com/github/krishkumawat0416-debug/PYTHON/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Customer_Call.xlsx - Call List.csv")

# %%
df.head(2)
# Out:
#    CustomerID First_Name Last_Name  Phone_Number                Address  \
# 0        1001      Frodo   Baggins  123-545-5421  123 Shire Lane, Shire
# 1        1002       Abed     Nadir  123/643/9775    93 West Main Street
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 0             Yes             No               True
# 1              No            Yes              False

# %%
numerical = df.select_dtypes(include="number").columns.to_list()
print("Numerical Columns")
print(numerical)
# Out:
# Numerical Columns
# ['CustomerID']

# %%
categorical = df.select_dtypes(include="object").columns.to_list()
print("Categorical Columns")
print(categorical)
# Out:
# Categorical Columns
# ['FIRSTNAME', 'LASTNAME', 'PHONE_NUMBER', 'Address', 'Paying Customer', 'Do_Not_Contact']

# %%
for i in categorical:
  print(df[i].value_counts())
  print()
# Out:
# FIRSTNAME
# Ron         2
# Anakin      2
# Frodo       1
# Walter      1
# Abed        1
# Jon         1
# Dwight      1
# Sherlock    1
# Gandalf     1
# Peter       1
# Jeff        1
# Samwise     1
# Harry       1
# Leslie      1
# Don         1
# Toby        1
# Michael     1
# Clark       1
# Creed       1
# Name: count, dtype: int64
#
# LASTNAME
# Skywalker      2
# Baggins        1
# /White         1
# Nadir          1
# Schrute        1
# Snow           1
#   Winger       1
# Swanson        1
# Unknown        1
# Parker         1
# Gamgee         1
# Holmes         1
# ...Potter      1
# Draper         1
# Flenderson_    1
# Knope          1
# Weasley        1
# Scott          1
# Kent           1
# Braton         1
# Name: count, dtype: int64
#
# PHONE_NUMBER
# 876|678|3469    5
# 123-545-5421    3
# 7066950392      3
# 123/643/9775    2
# 123-543-2345    2
# 304-762-2467    2
# Unknown         2
# N/a             2
# Name: count, dtype: int64
#
# Address
# ...

# %%
df.tail(2)
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 19        1020     Anakin  Skywalker  876|678|3469
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 19  910 Tatooine Road, Tatooine             Yes              N
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 19               True
# 20               True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 1.3+ KB

# %%
df.describe()
# Out:
#         CustomerID
# count    21.000000
# mean   1010.952381
# std       6.127611
# min    1001.000000
# 25%    1006.000000
# 50%    1011.000000
# 75%    1016.000000
# max    1020.000000

# %%
df = df.rename(columns={'First_Name': 'FIRSTNAME', 'Last_Name': 'LASTNAME',
               'Phone_Number':'PHONE_NUMBER'})
df
# Out:
#     CustomerID FIRSTNAME     LASTNAME  PHONE_NUMBER  \
# 0         1001     Frodo      Baggins  123-545-5421
# 1         1002      Abed        Nadir  123/643/9775
# 2         1003    Walter       /White    7066950392
# 3         1004    Dwight      Schrute  123-543-2345
# 4         1005       Jon         Snow  876|678|3469
# 5         1006       Ron      Swanson  304-762-2467
# 6         1007      Jeff       Winger           NaN
# 7         1008  Sherlock       Holmes  876|678|3469
# 8         1009   Gandalf          NaN           N/a
# 9         1010     Peter       Parker  123-545-5421
# 10        1011   Samwise       Gamgee           NaN
# 11        1012     Harry    ...Potter    7066950392
# 12        1013       Don       Draper  123-543-2345
# 13        1014    Leslie        Knope  876|678|3469
# 14        1015      Toby  Flenderson_  304-762-2467
# 15        1016       Ron      Weasley  123-545-5421
# 16        1017  Michael         Scott  123/643/9775
# ...

# %%
df.sort_values("FIRSTNAME")
# Out:
#     CustomerID FIRSTNAME     LASTNAME  PHONE_NUMBER  \
# 1         1002      Abed        Nadir  123/643/9775
# 20        1020    Anakin    Skywalker  876|678|3469
# 19        1020    Anakin    Skywalker  876|678|3469
# 17        1018     Clark         Kent    7066950392
# 18        1019     Creed       Braton           N/a
# 12        1013       Don       Draper  123-543-2345
# 3         1004    Dwight      Schrute  123-543-2345
# 0         1001     Frodo      Baggins  123-545-5421
# 8         1009   Gandalf          NaN           N/a
# 11        1012     Harry    ...Potter    7066950392
# 6         1007      Jeff       Winger           NaN
# 4         1005       Jon         Snow  876|678|3469
# 13        1014    Leslie        Knope  876|678|3469
# 16        1017  Michael         Scott  123/643/9775
# 9         1010     Peter       Parker  123-545-5421
# 5         1006       Ron      Swanson  304-762-2467
# 15        1016       Ron      Weasley  123-545-5421
# ...

# %%
df.sort_values("CustomerID")
# Out:
#     CustomerID FIRSTNAME     LASTNAME  PHONE_NUMBER  \
# 0         1001     Frodo      Baggins  123-545-5421
# 1         1002      Abed        Nadir  123/643/9775
# 2         1003    Walter       /White    7066950392
# 3         1004    Dwight      Schrute  123-543-2345
# 4         1005       Jon         Snow  876|678|3469
# 5         1006       Ron      Swanson  304-762-2467
# 6         1007      Jeff       Winger           NaN
# 7         1008  Sherlock       Holmes  876|678|3469
# 8         1009   Gandalf          NaN           N/a
# 9         1010     Peter       Parker  123-545-5421
# 10        1011   Samwise       Gamgee           NaN
# 11        1012     Harry    ...Potter    7066950392
# 12        1013       Don       Draper  123-543-2345
# 13        1014    Leslie        Knope  876|678|3469
# 14        1015      Toby  Flenderson_  304-762-2467
# 15        1016       Ron      Weasley  123-545-5421
# 16        1017  Michael         Scott  123/643/9775
# ...

# %%
df.sort_index()
# Out:
#     CustomerID FIRSTNAME     LASTNAME  PHONE_NUMBER  \
# 0         1001     Frodo      Baggins  123-545-5421
# 1         1002      Abed        Nadir  123/643/9775
# 2         1003    Walter       /White    7066950392
# 3         1004    Dwight      Schrute  123-543-2345
# 4         1005       Jon         Snow  876|678|3469
# 5         1006       Ron      Swanson  304-762-2467
# 6         1007      Jeff       Winger           NaN
# 7         1008  Sherlock       Holmes  876|678|3469
# 8         1009   Gandalf          NaN           N/a
# 9         1010     Peter       Parker  123-545-5421
# 10        1011   Samwise       Gamgee           NaN
# 11        1012     Harry    ...Potter    7066950392
# 12        1013       Don       Draper  123-543-2345
# 13        1014    Leslie        Knope  876|678|3469
# 14        1015      Toby  Flenderson_  304-762-2467
# 15        1016       Ron      Weasley  123-545-5421
# 16        1017  Michael         Scott  123/643/9775
# ...

# %%
df['CustomerID'] = df['CustomerID'].add(10)

# %%
df.head(2)
# Out:
#    CustomerID FIRSTNAME LASTNAME  PHONE_NUMBER                Address  \
# 0        1011     Frodo  Baggins  123-545-5421  123 Shire Lane, Shire
# 1        1012      Abed    Nadir  123/643/9775    93 West Main Street
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 0             Yes             No               True
# 1              No            Yes              False

# %%
df['CustomerID'] = df['CustomerID'].sub(20)

# %%
df.head(2)
# Out:
#    CustomerID FIRSTNAME LASTNAME  PHONE_NUMBER                Address  \
# 0         991     Frodo  Baggins  123-545-5421  123 Shire Lane, Shire
# 1         992      Abed    Nadir  123/643/9775    93 West Main Street
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 0             Yes             No               True
# 1              No            Yes              False

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# FIRSTNAME            0
# LASTNAME             1
# PHONE_NUMBER         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df['Do_Not_Contact'] = df['Do_Not_Contact'].fillna('Unknown')

# %%
df['Paying Customer'] = df['Paying Customer'].fillna(0)

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# FIRSTNAME            0
# LASTNAME             0
# PHONE_NUMBER         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df['PHONE_NUMBER'] = df['PHONE_NUMBER'].fillna(0)
df['LASTNAME'] = df['LASTNAME'].fillna(0)

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# FIRSTNAME            0
# LASTNAME             0
# PHONE_NUMBER         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df.loc[5:10]
# Out:
#     CustomerID FIRSTNAME  LASTNAME  PHONE_NUMBER                     Address  \
# 5          996       Ron   Swanson  304-762-2467            768 City Parkway
# 6          997      Jeff    Winger       Unknown           1209 South Street
# 7          998  Sherlock    Holmes  876|678|3469               98 Clue Drive
# 8          999   Gandalf   Unknown           N/a            123 Middle Earth
# 9         1000     Peter    Parker  123-545-5421  25th Main Street, New York
# 10        1001   Samwise    Gamgee       Unknown       612 Shire Lane, Shire
#
#    Paying Customer Do_Not_Contact  Not_Useful_Column
# 5              Yes        Unknown               True
# 6               No        Unknown              False
# 7                N        Unknown              False
# 8              Yes        Unknown              False
# 9              Yes        Unknown               True
# 10             Yes        Unknown               True

# %%
df.iloc[5:10]
# Out:
#    CustomerID FIRSTNAME  LASTNAME  PHONE_NUMBER                     Address  \
# 5         996       Ron   Swanson  304-762-2467            768 City Parkway
# 6         997      Jeff    Winger       Unknown           1209 South Street
# 7         998  Sherlock    Holmes  876|678|3469               98 Clue Drive
# 8         999   Gandalf   Unknown           N/a            123 Middle Earth
# 9        1000     Peter    Parker  123-545-5421  25th Main Street, New York
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 5             Yes        Unknown               True
# 6              No        Unknown              False
# 7               N        Unknown              False
# 8             Yes        Unknown              False
# 9             Yes        Unknown               True

# %%
df['Paying Customer'].value_counts()
# Out:
# Paying Customer
# Yes    11
# No      3
# N       3
# Y       3
# N/a     1
# Name: count, dtype: int64

# %%
df['Paying Customer'] = df['Paying Customer'].map({'Yes':1 , 'No':0 , 'N':2})

# %%
df.head(2)
# Out:
#    CustomerID FIRSTNAME LASTNAME  PHONE_NUMBER                Address  \
# 0         991     Frodo  Baggins  123-545-5421  123 Shire Lane, Shire
# 1         992      Abed    Nadir  123/643/9775    93 West Main Street
#
#    Paying Customer Do_Not_Contact  Not_Useful_Column
# 0              NaN        Unknown               True
# 1              NaN        Unknown              False

# %%
df.drop('Paying Customer',axis = 1)
# Out:
#     CustomerID FIRSTNAME     LASTNAME  PHONE_NUMBER  \
# 0          991     Frodo      Baggins  123-545-5421
# 1          992      Abed        Nadir  123/643/9775
# 2          993    Walter       /White    7066950392
# 3          994    Dwight      Schrute  123-543-2345
# 4          995       Jon         Snow  876|678|3469
# 5          996       Ron      Swanson  304-762-2467
# 6          997      Jeff       Winger       Unknown
# 7          998  Sherlock       Holmes  876|678|3469
# 8          999   Gandalf      Unknown           N/a
# 9         1000     Peter       Parker  123-545-5421
# 10        1001   Samwise       Gamgee       Unknown
# 11        1002     Harry    ...Potter    7066950392
# 12        1003       Don       Draper  123-543-2345
# 13        1004    Leslie        Knope  876|678|3469
# 14        1005      Toby  Flenderson_  304-762-2467
# 15        1006       Ron      Weasley  123-545-5421
# 16        1007  Michael         Scott  123/643/9775
# ...
