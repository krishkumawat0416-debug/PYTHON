# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\pc\Downloads\linkedin-reviews - linkedin-reviews.csv")

# %%
df.head()
# Out:
#                                               Review  Rating
# 0  Does absolutely nothing for a LinkedIn beginne...       1
# 1                            Force close(galaxy tab)       1
# 2  Slow and it tries to upload your contacts with...       1
# 3  Add ability to customize the profile and move ...       4
# 4  Good app, but it's a pain that it's not possib...       4

# %%
# !pip install textBlob

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  702 non-null    object
#  1   Rating  702 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 11.1+ KB

# %%
from textblob import TextBlob

# %%
# Plotting the Distribution of Ratings

# %%
sns.set(style = 'whitegrid')
plt.figure(figsize = (9,5))
sns.countplot(data = df , x = 'Rating')
plt.title('Distribution of Ratings')
plt.xlabel('Ratind')
plt.ylabel('Count')
plt.show()

# %%
def textblob_sentiment_analysis(review):
    sentiment = TextBlob(review).sentiment
    if sentiment.polarity > 0.1:
        return 'Positive'
    elif sentiment.polarity < -0.1:
        return 'Negative'
    else :
        return 'Neutral'

# %%
df['Sentiment'] = df['Review'].apply(textblob_sentiment_analysis)

# %%
df.sample(5)
# Out:
#                                                 Review  Rating Sentiment
# 592  Avoid version 2! Everything that was good is n...       1  Positive
# 624  Why does this app all of a sudden need to know...       2  Negative
# 384                      Not loading on my Galaxy Mini       1   Neutral
# 157  Creates ease of process and helps me provide t...       4   Neutral
# 639       Very poor. Roll back to first version please       1   Neutral

# %%
# Analyzing App Reviews Semtiments

# %%
sentiment_distribution = df['Sentiment'].value_counts()
sentiment_distribution
# Out:
# Sentiment
# Neutral     300
# Positive    295
# Negative    107
# Name: count, dtype: int64

# %%
plt.figure(figsize = (9,5))
sns.barplot(x = sentiment_distribution.index,
            y = sentiment_distribution.values)
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(data = df,
              x = 'Rating',
              hue = 'Sentiment')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.legend(title = 'Sentiment')
plt.show()

# %%
# Summary ---> App reviews Sentiment Analysis is a valuable tool for app developers and 
# business to understand user feedback, prioritize feature updates and maintain a positive
# user community. it involves using data analysis tchniques to determine whether the 
# sentiments in these review are positive,nagaitve or neutral
