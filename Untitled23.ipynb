# %% [markdown]
# <a href="https://colab.research.google.com/github/krishkumawat0416-debug/PYTHON/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
numerical = df.select_dtypes(include="number").columns.to_list()
print("Numerical Columns")
print(numerical)
# Out:
# Numerical Columns
# ['age', 'fever']

# %%
categorical = df.select_dtypes(include="object").columns.to_list()
print("Categorical Columns")
print(categorical)
# Out:
# Categorical Columns
# ['gender', 'cough', 'city', 'has_covid']

# %%
for i in categorical:
  print(df[i].value_counts())
  print()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64
#
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64
#
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64
#
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
for i in numerical:
  print(df[i])
  print()
# Out:
# 0     60
# 1     27
# 2     42
# 3     31
# 4     65
#       ..
# 95    12
# 96    51
# 97    20
# 98     5
# 99    10
# Name: age, Length: 100, dtype: int64
#
# 0     103.0
# 1     100.0
# 2     101.0
# 3      98.0
# 4     101.0
#       ...
# 95    104.0
# 96    101.0
# 97    101.0
# 98     98.0
# 99     98.0
# Name: fever, Length: 100, dtype: float64

# %%
a = df.isnull().sum()
a
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
a = df['fever'] = df['fever'].fillna(df['fever'].mean())
a
# Out:
# 0     103.0
# 1     100.0
# 2     101.0
# 3      98.0
# 4     101.0
#       ...
# 95    104.0
# 96    101.0
# 97    101.0
# 98     98.0
# 99     98.0
# Name: fever, Length: 100, dtype: float64

# %%
a = df.isnull().sum()
a
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
a = df.rename(columns={'age':'New Age','gender':'New Gender','has_covid':'Covid'})
a
# Out:
#     New Age New Gender  fever   cough       city Covid
# 0        60       Male  103.0    Mild    Kolkata    No
# 1        27       Male  100.0    Mild      Delhi   Yes
# 2        42       Male  101.0    Mild      Delhi    No
# 3        31     Female   98.0    Mild    Kolkata    No
# 4        65     Female  101.0    Mild     Mumbai    No
# ..      ...        ...    ...     ...        ...   ...
# 95       12     Female  104.0    Mild  Bangalore    No
# 96       51     Female  101.0  Strong    Kolkata   Yes
# 97       20     Female  101.0    Mild  Bangalore    No
# 98        5     Female   98.0  Strong     Mumbai    No
# 99       10     Female   98.0  Strong    Kolkata   Yes
#
# [100 rows x 6 columns]

# %%
row = df[categorical]
a = row.iloc[15:26]
a
# Out:
#     gender   cough       city has_covid
# 15    Male  Strong    Kolkata       Yes
# 16  Female    Mild    Kolkata       Yes
# 17  Female  Strong      Delhi        No
# 18  Female    Mild  Bangalore       Yes
# 19  Female  Strong  Bangalore       Yes
# 20    Male  Strong  Bangalore        No
# 21    Male    Mild  Bangalore       Yes
# 22  Female  Strong    Kolkata       Yes
# 23  Female    Mild      Delhi       Yes
# 24  Female  Strong    Kolkata        No
# 25    Male    Mild     Mumbai        No

# %%
a = df.describe()
a
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
a = df.to_csv("categorical_data_export.csv")
a

# %%
a = df.to_excel("numerical_data_export.xlsx")
a

# %%
a = df.sort_values('age')
a
# Out:
#     age  gender  fever   cough       city has_covid
# 88    5  Female  100.0    Mild    Kolkata        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 75    5    Male  102.0    Mild    Kolkata       Yes
# 59    6  Female  104.0    Mild    Kolkata       Yes
# 77    8  Female  101.0    Mild    Kolkata        No
# ..  ...     ...    ...     ...        ...       ...
# 41   82    Male    NaN    Mild    Kolkata       Yes
# 31   83    Male  103.0    Mild    Kolkata        No
# 53   83    Male   98.0    Mild      Delhi       Yes
# 72   83  Female  101.0    Mild    Kolkata        No
# 5    84  Female    NaN    Mild  Bangalore       Yes
#
# [100 rows x 6 columns]
