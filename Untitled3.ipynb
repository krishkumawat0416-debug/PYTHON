# %%
# EDA ===> Exploratory Data Analysis
# Parts of EDA

# ==> (1). Univariable Analysis ==> Analysis on a single independent column
# ==> (2). Bivariable Analysis ==> Anaylsis on two columns
# ==> (3). Multivariable Analysis ==> Analysis on more than 2 column

# %%
# Data Type
# (1). Nummerical Data ==> Continuous Data ==> Age(year, month, days), Height,
# (2). Categorical Data ==> Descrete Data ==> Total Number of Employees, Martial

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv(r"C:\Users\pc\Downloads\titanic - titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
 # 1 . Univariable Analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x = df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
 # If we want to see actual values then we use value_counts().
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# If we have Numerical data then we sue Histogram
# beacuse it finds the distribution

# %%
plt.hist(x=df['Age'])
plt.show()

# %%
# (2). Displot
# curve ==> KDE(KERnal DEnsity Extraction)
# use for find probability

# %%
sns.histplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.distplot(x=df['Age'] , hist = False)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16720\3332539379.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['Age'] , hist = False)
# <Axes: ylabel='Density'>

# %%
# (3). Boxplot
# for find our outliers

# (1). Lower fence
# (2). 25% data
# (3). IQR(Inter Quartile Range)(75%25%)
# (4). 75% data
# (5). upper fence

# %%
# x 1,2,3,4,5
# mean = (1+2+3+4+5)/5 = 15/5 = 3  ### HERE 100 IS OUTLER
# x = 1,2,3,4,5,100
# mean = 15+100/6 = 115/6 = 19.3

# %%
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>
