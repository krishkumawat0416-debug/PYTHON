# %% [markdown]
# <a href="https://colab.research.google.com/github/krishkumawat0416-debug/PYTHON/blob/main/CCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# cca --> complete case analysis

# df --> missing data --> filter missing data -->
# new_df -=> filtered _columns_in which we have missing data

# new_df --> missing data drop

# Architefcture --> histogram
# past column in which we have missing data
# updated column in which we have no missing data

# if past data architecture is overlap to new data architecture-->
# if means we can drop missing data
# if pasr data architecture is not overlap to new data architecture --->
# if means we cann not drip missing data . we will fill missing data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/dsjob - dsjob.csv")

# %%
df.head(2)
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
#
#    training_hours
# 0              21
# 1              98

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     0.000000
# gender                    23.860968
# relevent_experience        0.000000
# enrolled_university        1.456083
# education_level            2.442461
# major_discipline          14.654767
# experience                 0.234852
# company_size              29.215594
# company_type              29.779239
# last_new_job               1.878816
# training_hours             0.000000
# dtype: float64

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]
cols
# Out:
# ['enrolled_university', 'education_level', 'experience', 'last_new_job']

# %%
df[cols].sample(5)
# Out:
#      enrolled_university education_level experience last_new_job
# 1102       no_enrollment     High School          6            1
# 385     Full time course        Graduate          1        never
# 540        no_enrollment        Graduate          9            1
# 83         no_enrollment        Graduate          9           >4
# 1558       no_enrollment        Graduate          5            2

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          1269
# Masters            496
# High School        222
# Phd                 54
# Primary School      36
# Name: count, dtype: int64

# %%
len(df[cols].dropna()) / len(df)
# Out:
# 0.9478628464067638

# %%
new_df = df[cols].dropna()
df.shape , new_df.shape
# Out:
# ((2129, 13), (2018, 4))

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Original data
df['experience'].hist(bins = 50 , ax = ax , density = True ,color = 'red')

# data after cca , the argument alpha makes the color transparent , so we van
# see the overlay of the 2 distributions

new_df['experience'].hist(bins = 50 , ax = ax , color = 'green', density = True , alpha = 0.8)
# Out:
# <Axes: >

# %%
df = pd.read_csv('/content/covid_toy - covid_toy.csv')

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().mean()*100
# Out:
# age           0.0
# gender        0.0
# fever        10.0
# cough         0.0
# city          0.0
# has_covid     0.0
# dtype: float64

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.50 and df[var].isnull().mean() > 0]
cols
# Out:
# ['fever']

# %%
df[cols].sample(5)
# Out:
#     fever
# 5     NaN
# 99   98.0
# 6   101.0
# 3    98.0
# 11   98.0

# %%
df['fever'].value_counts()
# Out:
# fever
# 101.0    17
# 98.0     17
# 104.0    14
# 100.0    13
# 99.0     10
# 102.0    10
# 103.0     9
# Name: count, dtype: int64

# %%
len(df[cols].dropna()) / len(df)
# Out:
# 0.9

# %%
new_df = df[cols].dropna()
df.shape , new_df.shape
# Out:
# ((100, 6), (90, 1))

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df['fever'].hist(bins = 50 , ax = ax , density = True ,color = 'red')

new_df['fever'].hist(bins = 50 , ax = ax , color = 'green', density = True , alpha = 0.8)
# Out:
# <Axes: >

# %%
df = pd.read_csv('/content/titanic - titanic (1).csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.50 and df[var].isnull().mean() > 0]
cols
# Out:
# ['Age', 'Fare']

# %%
df['Age'].value_counts()
# Out:
# Age
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 44.0     1
# 5.0      1
# 51.0     1
# 3.0      1
# 38.5     1
# Name: count, Length: 79, dtype: int64

# %%
len(df[cols].dropna()) / len(df)
# Out:
# 0.7918660287081339

# %%
new_df = df[cols].dropna()
df.shape , new_df.shape
# Out:
# ((418, 12), (331, 2))

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df['Age'].hist(bins = 50 , ax = ax , density = True ,color = 'red')

new_df['Age'].hist(bins = 50 , ax = ax , color = 'green', density = True , alpha = 0.8)
# Out:
# <Axes: >
