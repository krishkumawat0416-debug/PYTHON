# %% [markdown]
# <a href="https://colab.research.google.com/github/krishkumawat0416-debug/PYTHON/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pipelining

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('newplacementdata.csv')

# %%
# finding the IQR
percentile25 = df['placement_exam_marks'].quantile(0.25)
percentile75 = df['placement_exam_marks'].quantile(0.75)

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(x=df['placement_exam_marks'])
plt.show()

# %%
percentile25
# Out:
# np.float64(17.0)

# %%
percentile75
# Out:
# np.float64(44.0)

# %%
iqr = percentile75 - percentile25

# %%
upper_limit = percentile75 + 1.5*iqr
# lower_limit = percentile25 - 1.5*iqr

# %%
lower_limit = percentile25 - 1.5*iqr

# %%
df[df['placement_exam_marks']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %%
#Trimming -->4(lower).....1 , upper(25)....(50)--> here 1,50 are outliers-->
#lower(4)<---> upper(25) mid data
#capping --> 4(lower)....1,upper(25)....(50)-->capping lower point lowest point(1)
#uper point upper point(50) ---> range expand ---> outlier removed

# %%
# Trimming (Outlier removing technique 1)

# %%
newf = df[df['placement_exam_marks'] < upper_limit]

# %%
plt.figure(figsize=(15,5))
plt.subplot(222)
sns.boxplot(x=df['placement_exam_marks'])

plt.subplot(224)
sns.boxplot(x=newf['placement_exam_marks'])
plt.show()

# %%
# Capping(Outlier Removing Technique 2)
new_df_cap = df.copy

# %%
# min = 5 , max = 15
# min 4 ,3, 1
# max 20 , 30 , 50
# update min value = 1
# update max value = 50

# %%
# Make a copy of the dataframe
new_df = df.copy()

# Replace outliers using np.where
new_df['placement_exam_marks'] = np.where(
    new_df['placement_exam_marks'] > upper_limit,
    upper_limit,
    np.where(
        new_df['placement_exam_marks'] < lower_limit,
        lower_limit,
        new_df['placement_exam_marks']
    )
)

# %%
plt.figure(figsize=(15,5))
plt.subplot(222)
sns.boxplot(x=new_df['placement_exam_marks'])

plt.subplot(224)
sns.boxplot(x=new_df['placement_exam_marks'])
plt.show()
