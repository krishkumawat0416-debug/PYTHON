# %% [markdown]
# <a href="https://colab.research.google.com/github/krishkumawat0416-debug/PYTHON/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('credit_scoring.csv')

# %%
df.head(5)
# Out:
#       Age          Gender   Marital Status Education Level  \
# 0      60            Male          Married          Master
# 1      25            Male          Married     High School
# 2  30\n58  Female\nFemale  Single\nMarried     Master\nPhD
# 3      32            Male          Married        Bachelor
# 4      42            Male         Divorced          Master
#
#          Employment Sta Credit Utilization
# 0              Employed               0.22
# 1            Unemployed                0.2
# 2  Employed\nUnemployed         0.22\n0.12
# 3         Self-Employed               0.99
# 4            Unemployed               0.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 34 non-null     object
#  1   Gender              34 non-null     object
#  2   Marital Status      34 non-null     object
#  3   Education Level     34 non-null     object
#  4   Employment Sta      34 non-null     object
#  5   Credit Utilization  34 non-null     object
# dtypes: object(6)
# memory usage: 1.7+ KB

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Marital Status        0
# Education Level       0
# Employment Sta        0
# Credit Utilization    0
# dtype: int64

# %%
X = df.drop(columns=['Gender'])
y = df['Gender']

# %%
num_cols = X.select_dtypes(include=['int64', 'float64']).columns
cat_cols = X.select_dtypes(include=['object']).columns

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(df.drop(
columns = ['Credit Utilization' ]) , df['Credit Utilization'] , test_size = 0.2)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Marital Status        0
# Education Level       0
# Employment Sta        0
# Credit Utilization    0
# dtype: int64

# %%
x_train
# Out:
#        Age          Gender      Marital Status        Education Level  \
# 2   30\n58  Female\nFemale     Single\nMarried            Master\nPhD
# 27      62            Male              Single                    PhD
# 14  61\n31    Male\nFemale     Married\nSingle          PhD\nBachelor
# 3       32            Male             Married               Bachelor
# 23  43\n46      Male\nMale     Single\nMarried     Bachelor\nBachelor
# 19      24            Male              Single            High School
# 30      34            Male             Married            High School
# 11  54\n34      Male\nMale    Divorced\nSingle    Master\nHigh School
# 26  41\n47      Male\nMale     Married\nSingle       Master\nBachelor
# 8   27\n52    Female\nMale  Divorced\nDivorced         Master\nMaster
# 0       60            Male             Married                 Master
# 33      60            Male              Single                    PhD
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
x_train_cough = oe.fit_transform(y_train.to_frame())
x_test_cough = oe.transform(y_test.to_frame())

x_train_cough.shape
# Out:
# (27, 1)

# %%
x_train_age = x_train.drop(columns=['Gender','Marital Status','Education Level','Employment Sta'],axis = 1).values
x_test_age = x_test.drop(columns=['Gender','Marital Status','Education Level','Employment Sta'],axis=1).values

# %%
x_train_age.shape
# Out:
# (27, 1)

# %%
import numpy as np
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

x_train_encoded = oe.fit_transform(x_train[['Marital Status', 'Employment Sta']])
x_test_encoded = oe.transform(x_test[['Marital Status', 'Employment Sta']])

x_train_transformed = np.concatenate((x_train_age, x_train_encoded), axis=1)
x_test_transformed = np.concatenate((x_test_age, x_test_encoded), axis=1)

# %%
x_test_transformed = np

# %%
df.head(4)
# Out:
#       Age          Gender   Marital Status Education Level  \
# 0      60            Male          Married          Master
# 1      25            Male          Married     High School
# 2  30\n58  Female\nFemale  Single\nMarried     Master\nPhD
# 3      32            Male          Married        Bachelor
#
#          Employment Sta Credit Utilization
# 0              Employed               0.22
# 1            Unemployed                0.2
# 2  Employed\nUnemployed         0.22\n0.12
# 3         Self-Employed               0.99

# %%
x_train_age.shape
# Out:
# (27, 1)

# %% [markdown]
# Syntax for ColumnTransformer:
#
# transformer = ColumnTransformer(transformers=[('imputer', SimpleImputer(), ['NumericalColumn1', 'NumericalColumn2']),('ordinal', OrdinalEncoder(), ['OrdinalColumn']),('onehot', OneHotEncoder(), ['CategoricalColumn1', 'CategoricalColumn2'])],remainder='passthrough')
